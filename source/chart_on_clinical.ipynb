# %% [markdown]
# Kiran-аас авсан клиикийн өгөгдлийг шинэчлэж түүн дээр зурлаа. 2024-02-24

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
ds = pd.read_csv('data/clinical_sample.csv', low_memory=False)
def filter(f):
    columns = ['clinical', 'day', 'binaryclassification', 'patient']
    x = ds[(ds['day']==f) & (ds['patient']==1)]
    # x = ds[(ds['day']==f)]
    x = x.drop(columns, axis = 1)
    x = x.iloc[:]
    return x.mean()

# %%
days = ['Day-1', 'Day-2', 'Day-3', 'Day-4', 'Day-5']
# color = ['g', 'b', 'k', 'm', 'r']
color = ['r', 'r', 'r', 'r', 'r']
colors = {'Day-1':'green', 'Day-2':'blue', 'Day-3':'black', 'Day-4':'magenta', 'Day-5':'red'}

labels = list(colors.keys())
handles = [plt.Rectangle((0,0),1,1, color=colors[label]) for label in labels]

# %%
plt.figure(figsize=(16,8))
plt.xlabel("Wavenumber ($\mathregular{cm^{-1}}$)")
plt.ylabel('Intensity (a.u.)')

for f in range(0, len(days)):
    x = filter(days[f])
    plt.plot(x.index, x.values, color=color[f], linestyle = '-', linewidth=2)
    if f == 0:
        plt.xticks(plt.xticks()[0][1::50])
        plt.legend(handles, labels)
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\m'
# <>:2: SyntaxWarning: invalid escape sequence '\m'
# /var/folders/bz/v1p77tsn4hbdl4zgynxf9wpm0000gn/T/ipykernel_1858/2278908772.py:2: SyntaxWarning: invalid escape sequence '\m'
#   plt.xlabel("Wavenumber ($\mathregular{cm^{-1}}$)")

# %%
fig = plt.figure(figsize=(8,6))
# fig.suptitle('Patient 2', fontsize=18)
gs = fig.add_gridspec(5, hspace=0.1)
axs = gs.subplots(sharex=True, sharey=True)

fig.text(0.06, 0.5, 'Intensity (a.u.)', ha='center', va='center', rotation='vertical')
fig.text(0.5, 0.04, 'Wavenumber ($\mathregular{cm^{-1}}$)', ha='center', va='center')
axs[0].text(0.48, 0.7, '1078 $\mathregular{cm^{-1}}$', color='black', fontsize=10,ha='center', va='bottom', transform=axs[0].transAxes)
axs[0].text(0.83, 0.7, '1582 $\mathregular{cm^{-1}}$', color='black', fontsize=10,ha='center', va='bottom', transform=axs[0].transAxes)
for f in range(0, len(days)):
    x = filter(days[f])
    axs[f].plot(x.index, x.values, color=color[f], linestyle = '-', linewidth=2, label = labels[f])
    # axs[f].legend(loc="upper left")
    handle = plt.Line2D([0], [0], color='none', linestyle='-', linewidth=2)  # No color

    axs[f].legend([handle], [labels[f]], loc="upper left")
    axs[f].axvline(x=756, color='black', linestyle='--', linewidth=1) # 1078
    axs[f].axvline(x=1260, color='black', linestyle='--', linewidth=1) # 1582    
    

    if f == 0:
        plt.xticks(plt.xticks()[0][1::100])

plt.savefig('diagram/clinical_sample_by_day_patient.eps', bbox_inches='tight')
# Out:
# <>:7: SyntaxWarning: invalid escape sequence '\m'
# <>:8: SyntaxWarning: invalid escape sequence '\m'
# <>:9: SyntaxWarning: invalid escape sequence '\m'
# <>:7: SyntaxWarning: invalid escape sequence '\m'
# <>:8: SyntaxWarning: invalid escape sequence '\m'
# <>:9: SyntaxWarning: invalid escape sequence '\m'
# /var/folders/bz/v1p77tsn4hbdl4zgynxf9wpm0000gn/T/ipykernel_1858/3875376706.py:7: SyntaxWarning: invalid escape sequence '\m'
#   fig.text(0.5, 0.04, 'Wavenumber ($\mathregular{cm^{-1}}$)', ha='center', va='center')
# /var/folders/bz/v1p77tsn4hbdl4zgynxf9wpm0000gn/T/ipykernel_1858/3875376706.py:8: SyntaxWarning: invalid escape sequence '\m'
#   axs[0].text(0.48, 0.7, '1078 $\mathregular{cm^{-1}}$', color='black', fontsize=10,ha='center', va='bottom', transform=axs[0].transAxes)
# /var/folders/bz/v1p77tsn4hbdl4zgynxf9wpm0000gn/T/ipykernel_1858/3875376706.py:9: SyntaxWarning: invalid escape sequence '\m'
# ...
